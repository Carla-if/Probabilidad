# %% [markdown]
# <a href="https://colab.research.google.com/github/Carla-if/Probabilidad/blob/main/Unidad%203/Ejercicio_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import math
import numpy as np

# %%
#Valores de la variable aleatoria
x=[0,10,20,50]
p=[0.50,0.30,0.15,0.05]

#Verificar suma=1
print("Suma de probabilidades:",sum(p))

plt.stem(x,p)
plt.title("Distribucion de Probabilidad")
plt.xlabel("Monto")
plt.ylabel("Probabilidad")
plt.grid(True)
plt.show()
# Out:
# Suma de probabilidades: 1.0

# %%
valor_esperado = 0
for i in range(len(x)):
  xi = x[i]
  pi = p[i]
  producto = xi * pi
  valor_esperado += producto

  print(f"x = {xi}, p = {pi}, x*p = {producto:.2f}")


  print(f"\nValor esperado (Esperanza): {valor_esperado:.2f}")
# Out:
# x = 0, p = 0.5, x*p = 0.00
#
# Valor esperado (Esperanza): 0.00
# x = 10, p = 0.3, x*p = 3.00
#
# Valor esperado (Esperanza): 3.00
# x = 20, p = 0.15, x*p = 3.00
#
# Valor esperado (Esperanza): 6.00
# x = 50, p = 0.05, x*p = 2.50
#
# Valor esperado (Esperanza): 8.50

# %%
esperanza = 0
for i in range (len(x)):
  esperanza +=x[i] * p[i]

  esperanza_cuadrado = 0
  for i in range(len(x)):
    esperanza_cuadrado += (x[i] **2) * p[i]

varianza = esperanza_cuadrado - esperanza ** 2
desviacion = math.sqrt(varianza)
# Mostrar resultados
print(f"E(X) = {esperanza:.2f}")
print(f"E(X^2) = {esperanza_cuadrado:.2f}")
print(f"Varianza = {varianza:.2f}")
print(f"Desviación estándar = {desviacion:.2f}")
# Out:
# E(X) = 8.50
# E(X^2) = 215.00
# Varianza = 142.75
# Desviación estándar = 11.95

# %%
# Calcular la funcion acumulada
F = np.cumsum(p)

#Mostrar resultados
for xi, fi in zip(x, F):
    print(f"F({xi}) = {fi:.2f}")

# Graficar
plt.step(x, F, where='post')
plt.title('Función de Distribución Acumulada (FDA)')
plt.xlabel("Monto")
plt.ylabel("Probabilidad acumulada")
plt.grid(True)
plt.ylim(0, 1.05)
plt.show()
# Out:
# F(0) = 0.50
# F(10) = 0.80
# F(20) = 0.95
# F(50) = 1.00
