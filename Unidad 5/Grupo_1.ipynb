# %% [markdown]
# <a href="https://colab.research.google.com/github/Carla-if/Probabilidad/blob/main/Unidad%205/Grupo_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib import pyplot
from sklearn.linear_model import LinearRegression
import numpy as np
from scipy.stats import pearsonr

# Cargamos el archivo del grupo 1
G1 = pd.read_csv('grupo1.csv')
G1.head()
# Out:
#    HorasEstudio  Calificacion
# 0         20.00         75.94
# 1         15.60         87.48
# 2         17.91         79.40
# 3         20.00         73.37
# 4         20.00         83.75

# %%
G1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 2 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   HorasEstudio  50 non-null     float64
#  1   Calificacion  50 non-null     float64
# dtypes: float64(2)
# memory usage: 932.0 bytes

# %%
# Mostramos la hora maxima de estudio
G1.HorasEstudio.max()
# Out:
# 20.0

# %%
# Mostramos la hora minima de estudio
G1.HorasEstudio.min()
# Out:
# 3.79

# %%
# Mostramos la calificacion maxima (mas alta)
G1.Calificacion.max()
# Out:
# 100.0

# %%
# Mostramos la calificacion minima (mas baja)
G1.Calificacion.min()
# Out:
# 68.46

# %%
# Mostrar los estadisticos descriptivos de la columna HorasEstudio
G1.HorasEstudio.describe()
# Out:
# count    50.000000
# mean     14.352000
# std       4.219174
# min       3.790000
# 25%      12.032500
# 50%      14.600000
# 75%      17.715000
# max      20.000000
# Name: HorasEstudio, dtype: float64

# %%
# Mostrar los estadisticos descriptivos de la columna Calificacion
G1.Calificacion.describe()
# Out:
# count     50.00000
# mean      83.78820
# std        7.83389
# min       68.46000
# 25%       78.03500
# 50%       84.49000
# 75%       88.09000
# max      100.00000
# Name: Calificacion, dtype: float64

# %%
# Histograma de calificaciones
# Calacular la media y guardarla en una variable para mostrarla en el histograma
media = G1.Calificacion.mean()
print(media)

plt.hist(G1.Calificacion, bins = 7)
plt.title('Histograma de Calificacion')
plt.axvline(media, color='y', linestyle='dashed', linewidth=2, label=f'Media={media:.2f}')
plt.xlabel('Calificacion')
plt.ylabel('frecuencia')
# Out:
# 83.7882
# Text(0, 0.5, 'frecuencia')

# %%
X = np.array(G1["HorasEstudio"]).reshape(-1, 1)
Y = G1["HorasEstudio"]

# Entrenar el modelo de regresion
modelo = LinearRegression()
modelo.fit(X, Y)

# Obtener la linea de regresion
pendiente = modelo.coef_[0]
intercepto = modelo.intercept_


print(f"Pendiente (m): {pendiente:.2f}")
print(f"Intercepto (b): {intercepto:.2f}")
print(f"Ecuacion de regresion: Y = {pendiente:.2f} * (X) + {intercepto:.2f}")
# Out:
# Pendiente (m): 1.00
# Intercepto (b): -0.00
# Ecuacion de regresion: Y = 1.00 * (X) + -0.00

# %%
# Definimos tamaño
plt.figure(figsize=(6, 4))

# Datos de entrada
Horas_Estudio = X
Calificacion = Y

# Creamos el diagrama de dispersion con la linea de regresion
sns.set(style="whitegrid")
sns.regplot(x=Horas_Estudio, y=Calificacion, scatter=True, color='blue')
plt.title('Diagrama de Dispersion y Regresion Lineal')
plt.xlabel('Horas de Estudio')
plt.ylabel('Calificacion')
plt.grid(True)
plt.show()

# %%
coeficiente_correlacion, p_valor = pearsonr(X.flatten(), Y)
print(f"Coeficiente de correlacion de Pearson:", coeficiente_correlacion)
print("Valor p:", p_valor)
# Out:
# Coeficiente de correlacion de Pearson: 1.0
# Valor p: 0.0
