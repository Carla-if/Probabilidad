# %% [markdown]
# <a href="https://colab.research.google.com/github/Carla-if/Probabilidad/blob/main/Unidad%201/Practica_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random
import matplotlib.pyplot as plt
from statistics import *

# %%
fabrica1 = []
for i in range(100):
  numero_aleatorio = round(random.uniform(50,100),2)
  fabrica1.append(numero_aleatorio)
print(fabrica1)
# Out:
# [59.45, 86.62, 89.5, 61.66, 93.96, 63.27, 71.52, 84.55, 94.5, 96.75, 73.04, 57.22, 65.53, 88.61, 87.99, 80.78, 63.95, 92.44, 72.3, 96.92, 63.92, 79.32, 84.74, 74.82, 62.05, 79.29, 56.89, 81.04, 98.23, 66.11, 96.37, 84.65, 56.16, 73.65, 82.99, 99.13, 65.82, 96.68, 63.01, 97.45, 67.27, 88.43, 97.27, 51.56, 95.12, 61.08, 80.79, 82.56, 85.24, 92.62, 53.88, 94.33, 60.73, 69.53, 60.5, 76.73, 96.58, 60.16, 86.25, 58.94, 84.52, 91.45, 63.67, 64.04, 65.03, 95.09, 83.21, 80.37, 54.1, 79.89, 83.24, 69.26, 64.56, 57.69, 62.76, 91.45, 89.7, 50.95, 91.7, 76.05, 53.14, 50.95, 68.02, 98.64, 85.5, 96.75, 65.18, 96.03, 51.16, 75.0, 63.71, 51.97, 62.09, 62.63, 50.54, 91.61, 94.69, 57.49, 85.37, 74.74]

# %%
fabrica2 = []
for i in range(100):
  numero_aleatorio = round(random.uniform(40,93),2)
  fabrica2.append(numero_aleatorio)
print(fabrica2)
# Out:
# [54.36, 60.82, 78.65, 74.08, 79.1, 60.27, 63.2, 59.14, 68.0, 82.61, 67.3, 70.74, 80.71, 76.71, 44.2, 46.38, 40.89, 70.64, 75.03, 50.66, 64.61, 84.0, 60.38, 64.86, 64.72, 40.41, 48.7, 53.95, 48.18, 46.3, 81.41, 76.79, 74.71, 47.79, 54.71, 63.07, 49.02, 70.13, 59.82, 64.84, 45.25, 65.45, 72.72, 56.05, 65.6, 44.73, 58.98, 56.43, 51.03, 54.65, 46.95, 73.94, 76.15, 70.81, 84.43, 73.53, 87.71, 87.63, 89.38, 67.4, 65.52, 91.91, 62.24, 45.04, 75.53, 70.93, 66.47, 70.27, 72.19, 73.45, 51.91, 41.48, 41.19, 91.44, 72.91, 91.94, 92.65, 50.93, 72.88, 56.34, 43.25, 75.49, 71.11, 90.65, 86.44, 64.55, 67.46, 40.65, 88.58, 56.75, 43.94, 79.69, 57.21, 71.54, 77.49, 79.34, 70.74, 52.58, 79.35, 85.25]

# %%
plt.boxplot(fabrica1)
plt.ylabel('Produccion en metros')
plt.title('Produccion de la fabrica 1')
plt.show()

# %%
plt.boxplot(fabrica2)
plt.ylabel('Produccion en metros')
plt.title('Produccion de la fabrica 2')
plt.show()

# %%
fig, (ax1, ax2) = plt.subplots(nrows=1, ncols=2, figsize=(10,5))
bplot1 = ax1.boxplot(fabrica1, vert=True, patch_artist=True)
ax1.set_title('Produccion de la fabrica 1')
ax1.set_ylabel('Produccion fabrica 1')
bplot1 = ax2.boxplot(fabrica2, vert=True, patch_artist=True)
ax2.set_title('Produccion de la fabrica 2')
plt.show()

# %%
fig, (ax1, ax2) = plt.subplots(nrows=1, ncols=2, figsize=(10,5))
bplot1 = ax1.boxplot(fabrica1, vert=True, patch_artist=True)
ax1.set_title('Produccion de la fabrica 1')
ax1.set_ylabel('Produccion fabrica 1')
bplot1 = ax2.boxplot(fabrica2, vert=True, patch_artist=True)
ax2.set_title('Produccion de la fabrica 2')
plt.show()
