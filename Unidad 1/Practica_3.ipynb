# %% [markdown]
# <a href="https://colab.research.google.com/github/Carla-if/Probabilidad/blob/main/Unidad%201/Practica_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image](https://github.com/JoseGabriel-ITD/Probabilidad-y-Estadistica/blob/main/Cintilla2004.png?raw=true)
#
# # **Probabilidad y estadística**
#
# ## Unidad 1
#
# ### Practica 3. Tabla de frecuencias y regla de sturges
#
# ### Facilitador: *Dr. José Gabriel Rodríguez Rivas*
#
# ### Alumno: Carla Iberia Carrillo Ferrer

# %%
# basado en el LIBRO estadística para administración pagina 12
# creamos una lista vacía que representa la edad de 100 personas
import random
edades = []
# Hacemos un ciclo para generar 100 numeros aleatorios que representan la edad de las personas
for i in range(100):
    # generamos un numero aleatorio con la funcion randint y lo guardamos en la variable numero_aleatorio
    numero_aleatorio = random.randint(18, 70)
    # Agregamos el numero aleatorio a la lista de valores
    edades.append(numero_aleatorio)
print(edades)
# Out:
# [54, 29, 20, 54, 45, 44, 57, 59, 53, 63, 62, 65, 48, 36, 26, 32, 49, 63, 30, 61, 65, 25, 59, 20, 56, 47, 51, 56, 48, 68, 62, 56, 30, 28, 69, 21, 35, 34, 26, 59, 54, 57, 21, 31, 68, 35, 69, 37, 19, 44, 19, 65, 28, 25, 21, 28, 54, 25, 39, 49, 43, 47, 36, 32, 27, 49, 58, 39, 45, 21, 63, 28, 34, 62, 23, 21, 62, 38, 26, 26, 60, 37, 52, 27, 57, 35, 56, 63, 53, 65, 22, 40, 31, 18, 36, 66, 61, 67, 51, 62]

# %%
import pandas as pd

# Crear un DataFrame de pandas con los números aleatorios
df = pd.DataFrame(edades, columns=['Edad'])
df.head()
# Out:
#    Edad
# 0    54
# 1    29
# 2    20
# 3    54
# 4    45

# %%
# Calcular la tabla de distribución de frecuencias
tabla_frecuencias = df['Edad'].value_counts().reset_index()
tabla_frecuencias.columns = ['Edad', 'Frecuencia']
tabla_frecuencias = tabla_frecuencias.sort_values(by='Edad')

# Imprimir la tabla de distribución de frecuencias
print("Tabla de Distribución de Frecuencias:")
tabla_frecuencias
# Out:
# Tabla de Distribución de Frecuencias:
#     Edad  Frecuencia
# 41    18           1
# 30    19           2
# 17    20           2
# 1     21           5
# 39    22           1
# 35    23           1
# 11    25           3
# 6     26           4
# 28    27           2
# 5     28           4
# 32    29           1
# 20    30           2
# 14    31           2
# 22    32           2
# 27    34           2
# 10    35           3
# 13    36           3
# 29    37           2
# 36    38           1
# 31    39           2
# 40    40           1
# 33    43           1
# 18    44           2
# 16    45           2
# 23    47           2
# 15    48           2
# 12    49           3
# 25    51           2
# 38    52           1
# 19    53           2
# 3     54           4
# 4     56           4
# 9     57           3
# 34    58           1
# 8     59           3
# 37    60           1
# 21    61           2
# 0     62           5
# 2     63           4
# 7     65           4
# 42    66           1
# 43    67           1
# 24    68           2
# 26    69           2

# %%
tabla_frecuencias["Frecuencia Relativa"] = tabla_frecuencias["Frecuencia"] / 100
tabla_frecuencias
# Out:
#     Edad  Frecuencia  Frecuencia Relativa
# 41    18           1                 0.01
# 30    19           2                 0.02
# 17    20           2                 0.02
# 1     21           5                 0.05
# 39    22           1                 0.01
# 35    23           1                 0.01
# 11    25           3                 0.03
# 6     26           4                 0.04
# 28    27           2                 0.02
# 5     28           4                 0.04
# 32    29           1                 0.01
# 20    30           2                 0.02
# 14    31           2                 0.02
# 22    32           2                 0.02
# 27    34           2                 0.02
# 10    35           3                 0.03
# 13    36           3                 0.03
# 29    37           2                 0.02
# 36    38           1                 0.01
# 31    39           2                 0.02
# 40    40           1                 0.01
# 33    43           1                 0.01
# 18    44           2                 0.02
# 16    45           2                 0.02
# 23    47           2                 0.02
# 15    48           2                 0.02
# 12    49           3                 0.03
# 25    51           2                 0.02
# 38    52           1                 0.01
# 19    53           2                 0.02
# 3     54           4                 0.04
# 4     56           4                 0.04
# 9     57           3                 0.03
# 34    58           1                 0.01
# 8     59           3                 0.03
# 37    60           1                 0.01
# 21    61           2                 0.02
# 0     62           5                 0.05
# 2     63           4                 0.04
# 7     65           4                 0.04
# 42    66           1                 0.01
# 43    67           1                 0.01
# 24    68           2                 0.02
# 26    69           2                 0.02

# %%
tabla_frecuencias["Fre Porcentaje"] = tabla_frecuencias["Frecuencia"] / 100 * 100
tabla_frecuencias
# Out:
#     Edad  Frecuencia  Frecuencia Relativa  Fre Porcentaje
# 41    18           1                 0.01             1.0
# 30    19           2                 0.02             2.0
# 17    20           2                 0.02             2.0
# 1     21           5                 0.05             5.0
# 39    22           1                 0.01             1.0
# 35    23           1                 0.01             1.0
# 11    25           3                 0.03             3.0
# 6     26           4                 0.04             4.0
# 28    27           2                 0.02             2.0
# 5     28           4                 0.04             4.0
# 32    29           1                 0.01             1.0
# 20    30           2                 0.02             2.0
# 14    31           2                 0.02             2.0
# 22    32           2                 0.02             2.0
# 27    34           2                 0.02             2.0
# 10    35           3                 0.03             3.0
# 13    36           3                 0.03             3.0
# 29    37           2                 0.02             2.0
# 36    38           1                 0.01             1.0
# 31    39           2                 0.02             2.0
# 40    40           1                 0.01             1.0
# 33    43           1                 0.01             1.0
# 18    44           2                 0.02             2.0
# 16    45           2                 0.02             2.0
# 23    47           2                 0.02             2.0
# 15    48           2                 0.02             2.0
# 12    49           3                 0.03             3.0
# 25    51           2                 0.02             2.0
# 38    52           1                 0.01             1.0
# 19    53           2                 0.02             2.0
# 3     54           4                 0.04             4.0
# 4     56           4                 0.04             4.0
# 9     57           3                 0.03             3.0
# 34    58           1                 0.01             1.0
# 8     59           3                 0.03             3.0
# 37    60           1                 0.01             1.0
# 21    61           2                 0.02             2.0
# 0     62           5                 0.05             5.0
# 2     63           4                 0.04             4.0
# 7     65           4                 0.04             4.0
# 42    66           1                 0.01             1.0
# 43    67           1                 0.01             1.0
# 24    68           2                 0.02             2.0
# 26    69           2                 0.02             2.0

# %%
tabla_frecuencias["Frecuencia Acumulada"] = tabla_frecuencias["Frecuencia"].cumsum()

# %%
# Importamos la librería math de funciones matemáticas
import math
# Volvemos a usar la lista edades
print(edades)
# Out:
# [54, 29, 20, 54, 45, 44, 57, 59, 53, 63, 62, 65, 48, 36, 26, 32, 49, 63, 30, 61, 65, 25, 59, 20, 56, 47, 51, 56, 48, 68, 62, 56, 30, 28, 69, 21, 35, 34, 26, 59, 54, 57, 21, 31, 68, 35, 69, 37, 19, 44, 19, 65, 28, 25, 21, 28, 54, 25, 39, 49, 43, 47, 36, 32, 27, 49, 58, 39, 45, 21, 63, 28, 34, 62, 23, 21, 62, 38, 26, 26, 60, 37, 52, 27, 57, 35, 56, 63, 53, 65, 22, 40, 31, 18, 36, 66, 61, 67, 51, 62]

# %%
# Crear un DataFrame con las edades
df = pd.DataFrame({'Edad': edades})
df
# Out:
#     Edad
# 0     54
# 1     29
# 2     20
# 3     54
# 4     45
# ..   ...
# 95    66
# 96    61
# 97    67
# 98    51
# 99    62
#
# [100 rows x 1 columns]

# %%
# Calcular el número de intervalos utilizando la regla de Sturges
n = len(edades)
K = int(1 + math.log2(n))

print("Valor de n = ", n, "\nNúmero de intervalos = ", K)
# Crear la tabla de frecuencia
# Out:
# Valor de n =  100
# Número de intervalos =  7

# %%
 #Crear la tabla de frecuencia

tabla_frecuencia = pd.cut(df['Edad'], bins=K, include_lowest=True).value_counts().reset_index()
tabla_frecuencia.columns = ['Clase', 'Frec']
tabla_frecuencia
# Out:
#               Clase  Frec
# 0    (61.714, 69.0]    19
# 1  (25.286, 32.571]    17
# 2  (17.948, 25.286]    15
# 3  (54.429, 61.714]    14
# 4  (47.143, 54.429]    14
# 5  (32.571, 39.857]    13
# 6  (39.857, 47.143]     8

# %%
# Ordenar la tabla de frecuencia por el intervalo
tabla_frecuencia = tabla_frecuencia.sort_values(by='Clase')
tabla_frecuencia
# Out:
#               Clase  Frec
# 2  (17.948, 25.286]    15
# 1  (25.286, 32.571]    17
# 5  (32.571, 39.857]    13
# 6  (39.857, 47.143]     8
# 4  (47.143, 54.429]    14
# 3  (54.429, 61.714]    14
# 0    (61.714, 69.0]    19

# %%
# Generar columnas siguientes
tabla_frecuencia['Frec Rel'] = tabla_frecuencia['Frec'] / n
tabla_frecuencia['Frec Porc'] = tabla_frecuencia['Frec'] / n * 100
tabla_frecuencia['Frec Rel Ac'] = tabla_frecuencia['Frec Rel'].cumsum()
tabla_frecuencia['Frec Porc Ac'] = tabla_frecuencia['Frec Porc'].cumsum()

# Mostrar la tabla de frecuencia
print(tabla_frecuencia)
# Out:
#               Clase  Frec  Frec Rel  Frec Porc  Frec Rel Ac  Frec Porc Ac
# 2  (17.948, 25.286]    15      0.15       15.0         0.15          15.0
# 1  (25.286, 32.571]    17      0.17       17.0         0.32          32.0
# 5  (32.571, 39.857]    13      0.13       13.0         0.45          45.0
# 6  (39.857, 47.143]     8      0.08        8.0         0.53          53.0
# 4  (47.143, 54.429]    14      0.14       14.0         0.67          67.0
# 3  (54.429, 61.714]    14      0.14       14.0         0.81          81.0
# 0    (61.714, 69.0]    19      0.19       19.0         1.00         100.0

# %%
import matplotlib.pyplot as plt

plt.hist(edades, alpha = 0.5)
plt.title("Histograma de edades basado en la función de matplotlib con valores estándar")
# Out:
# Text(0.5, 1.0, 'Histograma de edades basado en la función de matplotlib con valores estándar')

# %%
# Crear un histograma basado en la tabla de frecuencia
plt.hist(df['Edad'], bins=K, alpha=0.5)
plt.title('Histograma de edades basado en la regla de Sturges')
plt.xlabel('Edades')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')
